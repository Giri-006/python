# %%
import numpy as np

# %%
a = [1, 2, 3]

# %%
arr = np.array(a)

# %%
arr
# Out:
# array([1, 2, 3])

# %%
a = (1, 2, 3)
arr1 = np.array(a)

# %%
arr1
# Out:
# array([1, 2, 3])

# %%
arr = np.array([6, 7, np.nan, 9, 10])
arr
# Out:
# array([ 6.,  7., nan,  9., 10.])

# %%
arr = arr[~np.isnan(arr)]

# %%
arr
# Out:
# array([ 6.,  7.,  9., 10.])

# %%
mean = np.nanmean(arr)

# %%
mean
# Out:
# np.float64(8.0)

# %%
# x = 6, 7, nan, 9, 10  -- 1,000,000 - 20% -- 800,000
# y - independent varirable
# x - dependent variable
# x - attribute, column, features

# %%
arr = np.array([6, 7, np.nan, 9, 10])
arr
# Out:
# array([ 6.,  7., nan,  9., 10.])

# %%
arr = np.nan_to_num(arr, nan = mean)
arr
# Out:
# array([ 6.,  7.,  8.,  9., 10.])

# %%
# pandas - library - structured data

# %%
import pandas as pd

# %%
d = [1, 2, 3, 4, 5]
d
# Out:
# [1, 2, 3, 4, 5]

# %%
e = (1, 2, 3, 4, 5)
e
# Out:
# (1, 2, 3, 4, 5)

# %%
df = pd.Series(d)

# %%
df
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
df = pd.Series(e)

# %%
df
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
dic = {'a': 1, 'b': 2, 'c':3}
df = pd.Series(dic)
df
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
a = ['a', 'b', 'c']
b = [10, 20, 30]
df = pd.Series(b)
df
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
df = pd.Series(b, index = a)

# %%
df
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
d = {'id': ['a', 'b', 'c'], 'mark': [100, 90, 80], 'name': ['Damien', 'stefan','Elena']}
df = pd.Series(d)
df
# Out:
# id                    [a, b, c]
# mark              [100, 90, 80]
# name    [Damien, stefan, Elena]
# dtype: object

# %%
df = pd.DataFrame(d)
df
# Out:
#   id  mark    name
# 0  a   100  Damien
# 1  b    90  stefan
# 2  c    80   Elena

# %%
# when the data is very small to process - pandas

# %%
# decorators
# it takes another function as it input
# it adds an extra behaviour to existing function
# it returns new function

# %%
def addition(a, b):
    return a + b

# %%
addition(10, 20)
# Out:
# 30

# %%
def my_decorator(func):
    print(f"Before add function")
    def add():
        print(f"Inside add method/function")
        func()
        print(f"After func call")
    return add
    print(f"End of decorator fucntion")

# %%
@my_decorator
def trigger_this():
    print(f"I am inside trigger method")
# Out:
# Before add function

# %%
trigger_this()
# Out:
# Inside add method/function
# I am inside trigger method
# After func call

# %%
def my_decorator(func):
    print(f"before add function")
    def add_num(*args, **kwargs):
        print(f"IPnside add method/fucntion")
        return func(*args, **kwargs)
        print(f"After func call")
    return add_num
    print(f"end of decorator")

# %%
@my_decorator
def trigger_this(p_return):
    print(f"{p_return}")
# Out:
# before add function

# %%
trigger_this("Trigger this method")
# Out:
# IPnside add method/fucntion
# Trigger this method

# %%
def first_function():
    print("Inside first fucntion")
    def second_function():
        print("INside second funtion")

# %%
second_function()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 second_function()
#
# NameError: name 'second_function' is not defined

# %%
def add_num(*args):
    print(args, type(args))

# %%
add_num(1)
# Out:
# (1,) <class 'tuple'>

# %%
add_num('a')
# Out:
# ('a',) <class 'tuple'>

# %%
add_num('a', 'b')
# Out:
# ('a', 'b') <class 'tuple'>

# %%
add_num('a', 'b', 'c', 'd')
# Out:
# ('a', 'b', 'c', 'd') <class 'tuple'>

# %%
def check_multiply(*args):
    result = 1
    for i in args:
        result *= i # result = result * i
    return result

# %%
print(check_multiply(2, 3, 4))
# Out:
# 24

# %%
# kargs - keyword arguments, keys will be its argument name 
# * args - positional args
# **kwargs - keyword args

# %%
'''
tuple                  dict
Yes                     NO
Indexing method         specify the key pari '''

# %%
def define_kwargs(**kwargs):
    print(kwargs, type(kwargs))

# %%
define_kwargs(first_argument = 'Welcome', second_argument = 'Home')
# Out:
# {'first_argument': 'Welcome', 'second_argument': 'Home'} <class 'dict'>

# %%
def args_kwargs(*args, **kwargs):
    print(f"My args are {args}")
    print(f"My kwargs are {kwargs}")

# %%
args_kwargs(111, 222, first_argument = 'Welcome', second_argument = 'Home')
# Out:
# My args are (111, 222)
# My kwargs are {'first_argument': 'Welcome', 'second_argument': 'Home'}

# %%
args_kwargs(11, 222)
# Out:
# My args are (11, 222)
# My kwargs are {}

# %%
def args_kwargs(*args, **kwargs):
    print(f"My args are {args}")
    print(f"My kargs are {kwargs}")
    print(args[0])
    print(kwargs['second_argument'])

# %%
args_kwargs(111, 222, 333, first_argument = 'Welcome', second_argument = 'Home')
# Out:
# My args are (111, 222, 333)
# My kargs are {'first_argument': 'Welcome', 'second_argument': 'Home'}
# 111
# Home
